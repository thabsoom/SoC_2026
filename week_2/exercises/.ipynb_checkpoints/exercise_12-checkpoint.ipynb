# %% [markdown]
# # GridSearchCV

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.datasets import load_digits
digits=load_digits()
dir(df)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
mo = {
    'svm' : { 'model':svm.SVC(gamma='auto'), 'params': { 'C':[1,10,100], 'kernel':['rbf','linear']}},
    'Randomforest': {'model':RandomForestClassifier(), 'params':{ 'n_estimators':[1,5,10] }},
    'LogisticRegression':{'model':LogisticRegression(max_iter=1000), 'params':{'C':[1,5,10]}},
    'naive_bayes_gaussian': { 'model': GaussianNB(), 'params': {}},
    'naive_bayes_multinomial': { 'model': MultinomialNB(), 'params': {} },
    'decision_tree': {'model': DecisionTreeClassifier(),'params': {'criterion': ['gini','entropy']}}
}

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
scores=[]
for model,mp in mo.items():
    clf=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
    clf.fit(digits.data,digits.target)
    scores.append({'model':mp['model'],'best_score':clf.best_score_, 'best_params':clf.best_params_})
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                                model  best_score                   best_params
# 0                  SVC(gamma='auto')    0.947697  {'C': 1, 'kernel': 'linear'}
# 1           RandomForestClassifier()    0.888171          {'n_estimators': 10}
# 2  LogisticRegression(max_iter=1000)    0.914878                      {'C': 1}
# 3                       GaussianNB()    0.806928                            {}
# 4                    MultinomialNB()    0.870350                            {}
# 5           DecisionTreeClassifier()    0.814714      {'criterion': 'entropy'}
