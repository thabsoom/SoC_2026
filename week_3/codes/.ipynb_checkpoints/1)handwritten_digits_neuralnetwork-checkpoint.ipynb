# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test,y_test) = keras.datasets.mnist.load_data()

# %%
plt.matshow(X_train[1])

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train=X_train/255
X_test=X_test/255

# %%
#flatten array
X_train_flattened=X_train.reshape(len(X_train),28*28)
X_test_flattened=X_test.reshape(len(X_test),28*28)

# %%
model=keras.Sequential([
    keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train_flattened,y_train,epochs=5)
# Out:
# C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8771 - loss: 0.4691
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9155 - loss: 0.3037
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9210 - loss: 0.2833
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9237 - loss: 0.2728
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9254 - loss: 0.2662

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9247 - loss: 0.2675
# [0.2675415277481079, 0.9247000217437744]

# %%
plt.matshow(X_test[0])

# %%
y_pred=model.predict(X_test_flattened)
y_pred[0]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([3.1176420e-02, 6.1539231e-07, 5.1298816e-02, 9.6802443e-01,
#        4.9041328e-03, 1.4076440e-01, 2.2094405e-06, 9.9985260e-01,
#        8.9281030e-02, 7.1377343e-01], dtype=float32)

# %%
np.argmax(y_pred[0])
# Out:
# np.int64(7)

# %%
y_predicted_labels=[np.argmax(i) for i in y_pred]

# %%
cm=tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 961,    0,    2,    2,    0,    5,    7,    2,    1,    0],
#        [   0, 1111,    3,    2,    0,    1,    4,    2,   12,    0],
#        [   5,    9,  926,   15,    9,    6,   13,   11,   34,    4],
#        [   4,    0,   20,  920,    1,   27,    3,   11,   16,    8],
#        [   1,    1,    3,    1,  917,    0,   12,    4,    8,   35],
#        [   9,    2,    3,   26,   10,  791,   13,    7,   24,    7],
#        [   9,    3,    5,    1,    8,   14,  915,    2,    1,    0],
#        [   1,    5,   21,    5,    8,    0,    0,  951,    2,   35],
#        [   8,    7,    8,   24,    9,   47,    9,   12,  838,   12],
#        [  11,    7,    1,   11,   30,    8,    0,   22,    2,  917]],
#       dtype=int32)>

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predcited')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model=keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train_flattened,y_train,epochs=5)
# Out:
# C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9247 - loss: 0.2689
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9646 - loss: 0.1212
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9742 - loss: 0.0852
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9805 - loss: 0.0635
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9837 - loss: 0.0510

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9762 - loss: 0.0826
# [0.082639679312706, 0.9761999845504761]

# %%
y_pred=model.predict(X_test_flattened)
y_pred_labels=[np.argmax(i) for i in y_pred]
cm=tf.math.confusion_matrix(labels=y_test,predictions=y_pred_labels)
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Pedicted')
plt.ylabel('Truth')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step
# Text(95.72222222222221, 0.5, 'Truth')

# %%
# !pip install TensorBoard
# Out:
# Collecting TensorBoard
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=0.4 in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from TensorBoard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from TensorBoard) (1.81.0)
# Collecting markdown>=2.6.8 (from TensorBoard)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from TensorBoard) (2.3.2)
# Requirement already satisfied: packaging in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from TensorBoard) (25.0)
# Requirement already satisfied: pillow in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from TensorBoard) (11.3.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from TensorBoard) (7.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from TensorBoard) (80.9.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from TensorBoard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from TensorBoard)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: typing-extensions~=4.12 in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from grpcio>=1.48.2->TensorBoard) (4.14.1)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\farah\AppData\Local\Programs\Python\Python313\Lib\site-packages (from werkzeug>=1.0.1->TensorBoard) (3.0.2)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 1.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/5.5 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.0/5.5 MB 1.4 MB/s eta 0:00:04
#    ------- -------------------------------- 1.0/5.5 MB 1.4 MB/s eta 0:00:04
#    --------- ------------------------------ 1.3/5.5 MB 1.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 1.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 1.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 1.2 MB/s eta 0:00:04
#    ------------- -------------------------- 1.8/5.5 MB 828.3 kB/s eta 0:00:05
#    ------------- -------------------------- 1.8/5.5 MB 828.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 823.3 kB/s eta 0:00:05
#    ----------------- ---------------------- 2.4/5.5 MB 516.7 kB/s eta 0:00:07
#    ------------------ --------------------- 2.6/5.5 MB 539.6 kB/s eta 0:00:06
#    ------------------ --------------------- 2.6/5.5 MB 539.6 kB/s eta 0:00:06
#    ------------------ --------------------- 2.6/5.5 MB 539.6 kB/s eta 0:00:06
#    ------------------ --------------------- 2.6/5.5 MB 539.6 kB/s eta 0:00:06
#    -------------------- ------------------- 2.9/5.5 MB 498.9 kB/s eta 0:00:06
#    -------------------- ------------------- 2.9/5.5 MB 498.9 kB/s eta 0:00:06
#    -------------------- ------------------- 2.9/5.5 MB 498.9 kB/s eta 0:00:06
#    -------------------- ------------------- 2.9/5.5 MB 498.9 kB/s eta 0:00:06
#    ---------------------- ----------------- 3.1/5.5 MB 481.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 3.1/5.5 MB 481.9 kB/s eta 0:00:05
#    ------------------------ --------------- 3.4/5.5 MB 478.1 kB/s eta 0:00:05
#    -------------------------- ------------- 3.7/5.5 MB 502.3 kB/s eta 0:00:04
#    -------------------------- ------------- 3.7/5.5 MB 502.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 3.9/5.5 MB 519.9 kB/s eta 0:00:04
#    ------------------------------ --------- 4.2/5.5 MB 532.1 kB/s eta 0:00:03
#    ---------------------------------- ----- 4.7/5.5 MB 589.7 kB/s eta 0:00:02
#    ------------------------------------ --- 5.0/5.5 MB 608.4 kB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 608.4 kB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 611.4 kB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 611.4 kB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 611.4 kB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 611.4 kB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 588.0 kB/s  0:00:09
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, markdown, TensorBoard
#
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    ---------------------------------------- 0/4 [werkzeug]
#    -------------------- ------------------- 2/4 [markdown]
#    -------------------- ------------------- 2/4 [markdown]
#    -------------------- ------------------- 2/4 [markdown]
#    -------------------- ------------------- 2/4 [markdown]
#    -------------------- ------------------- 2/4 [markdown]
#    -------------------- ------------------- 2/4 [markdown]
#    -------------------- ------------------- 2/4 [markdown]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ------------------------------ --------- 3/4 [TensorBoard]
#    ---------------------------------------- 4/4 [TensorBoard]
#
# Successfully installed TensorBoard-2.20.0 markdown-3.10.2 tensorboard-data-server-0.7.2 werkzeug-3.1.8

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])
tb_callback = tf.keras.callbacks.TensorBoard(log_dir="logs/",histogram_freq=1)
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train,y_train,epochs=5, callbacks=[tb_callback])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9238 - loss: 0.2713
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9634 - loss: 0.1236
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9744 - loss: 0.0855
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9799 - loss: 0.0651
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9844 - loss: 0.0518
